# %%
import pandas as pd
import numpy as np
import ast
import json
from datetime import datetime

# %%
dfitems = pd.read_pickle('dfitems.pkl') # Desglosa la columna items de la tabla items, 
#user_id     item_id     item_name   playtime_forever    playtime_2weeks

items_count = pd.read_pickle('items_count') # es una la tabla items pero sin la columna items.
#user_id     items_count     steam_id    user_url

steams = pd.read_pickle('steams.pkl') # es la tabla steams

# %%
dfitems
# Out:
#                    user_id item_id                      item_name  \
# 0        76561197970982479      10                 Counter-Strike
# 1        76561197970982479      20          Team Fortress Classic
# 2        76561197970982479      30                  Day of Defeat
# 3        76561197970982479      40             Deathmatch Classic
# 4        76561197970982479      50      Half-Life: Opposing Force
# ...                    ...     ...                            ...
# 5153204  76561198329548331  346330                   BrainBread 2
# 5153205  76561198329548331  373330                    All Is Dust
# 5153206  76561198329548331  388490  One Way To Die: Steam Edition
# 5153207  76561198329548331  521570          You Have 10 Seconds 2
# 5153208  76561198329548331  519140                     Minds Eyes
#
#          playtime_forever  playtime_2weeks
# 0                       6                0
# 1                       0                0
# ...

# %%
dfgroup1 = dfitems.groupby(['item_id']).sum().reset_index()
dfgroup1
# Out:
#       item_id  playtime_forever  playtime_2weeks
# 0          10          17386015            48774
# 1         100            311999             1170
# 2       10000             63046                0
# 3        1002               894                0
# 4       10040                 0                0
# ...       ...               ...              ...
# 10973   99890            128136                0
# 10974    9990              2110                0
# 10975   99900          17259605            57500
# 10976   99910            426680             1204
# 10977   99920              2344                0
#
# [10978 rows x 3 columns]

# %%
dfgroup1 = dfgroup1.sort_values('playtime_forever', ascending= False)

# %%
steams.loc[steams['title']=='Counter-Strike: Global Offensive']
# Out:
#       publisher    genres                          app_name  \
# 89355     Valve  [Action]  Counter-Strike: Global Offensive
#
#                                   title  \
# 89355  Counter-Strike: Global Offensive
#
#                                                      url release_date  \
# 89355  http://store.steampowered.com/app/730/CounterS...   2012-08-21
#
#                                                     tags  \
# 89355  [FPS, Multiplayer, Shooter, Action, Team-Based...
#
#                                              reviews_url  \
# 89355  http://steamcommunity.com/app/730/reviews/?bro...
#
#                                                    specs  price early_access  \
# 89355  [Multi-player, Steam Achievements, Full contro...  14.99        False
#
#         id developer
# 89355  730     Valve

# %%
steams = steams.rename(columns={'id':'item_id'})
steams
# Out:
#                   publisher  \
# 88310             Kotoshiro
# 88311      Making Fun, Inc.
# 88312          Poolians.com
# 88313                  彼岸领域
# 88315   Trickjump Games Ltd
# ...                     ...
# 120439      Bidoniera Games
# 120440      Ghost_RUS Games
# 120441               Sacada
# 120442         Laush Studio
# 120443             SIXNAILS
#
#                                                    genres  \
# 88310       [Action, Casual, Indie, Simulation, Strategy]
# 88311                [Free to Play, Indie, RPG, Strategy]
# 88312   [Casual, Free to Play, Indie, Simulation, Sports]
# 88313                         [Action, Adventure, Casual]
# 88315                     [Action, Adventure, Simulation]
# ...                                                   ...
# 120439                 [Action, Adventure, Casual, Indie]
# 120440              [Casual, Indie, Simulation, Strategy]
# 120441                          [Casual, Indie, Strategy]
# ...

# %%
dfgroup1['item_id'] = dfgroup1['item_id'].astype(int)
steams['item_id'] = steams['item_id'].astype(int)  
dfgroup1.dtypes
# Out:
# item_id             int32
# playtime_forever    int64
# playtime_2weeks     int64
# dtype: object

# %%
steams = steams.rename(columns={'id': 'item_id'})
join = dfgroup1.merge(steams, on='item_id', how= 'inner')

# %%
join_red = join[['item_id', 'playtime_forever', 'genres', 'title']]

# %%
a = list(join_red['genres'])# tiene la lista de los items (lista de listas) 88310
listalarga = [item for sublist in a for item in sublist]    # esta lista es una lista con todos las reviews de dimension mayor a "a" 5153209
lista_n = [len (q) for q in a]  # esta lista tiene la cantidad n de elementos de la lista
lista_items = list(join_red['item_id'])   #dimension = a 'a' 88310
lista_playtime = list(join_red['item_id'])
def repetir_elementos(lista_n, lista_u):
    resultado = []
    for i in range(len(lista_n)):
        resultado.extend([lista_u[i]] * lista_n[i])
    return resultado

listadf = repetir_elementos(lista_n, lista_items)
dfjuntado = pd.DataFrame(listalarga, )
dfjuntado.insert(0,'item_list', listadf)
respuesta3 = dfjuntado.merge(join_red[['item_id','playtime_forever']], left_on='item_list', right_on = 'item_id').drop(columns=['item_id'])
respuesta3 = respuesta3.rename(columns= {0:'genre'})
#respuesta3

respuesta3 = respuesta3.groupby(by='genre', as_index=False).sum().sort_values(by='playtime_forever', ascending= False)
#respuesta3 = respuesta3
#respuesta3.to_pickle('respuesta3.pkl')

# %%
dfjuntado.columns=['item_id', 'genres']
dfjuntado.to_pickle('item_genres.pkl')

# %%
respuesta3
# Out:
#                         genre   item_list  playtime_forever
# 0                      Action  1160700088        3101967165
# 9                       Indie  1795848609        1489435080
# 12                        RPG   483392821        1040139848
# 1                   Adventure   978040035         903907771
# 14                 Simulation   422745317         865522358
# 17                   Strategy   574937729         658677495
# 8                Free to Play   151802943         606103140
# 10      Massively Multiplayer    77602293         445879305
# 4                      Casual   767347439         249926499
# 6                Early Access   181485120         158580461
# 16                     Sports    98987960          65812127
# 13                     Racing    93967967          62381965
# 18                  Utilities    23301982           4438436
# 5   Design &amp; Illustration    18943962           4102258
# 20             Web Publishing     4929730           2761755
# ...
