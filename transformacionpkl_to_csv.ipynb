# %%
import pandas as pd
import numpy as np
import ast
import json
from datetime import datetime
import os

# %%
pkl_files = [file for file in os.listdir() if '.pkl' in file]
pkl_files

for file in pkl_files:
    steams = pd.read_pickle(file) # es la tabla steams
    csv_name = file.replace(".pkl", ".csv")
    steams.to_csv(csv_name, index=False)
    print(csv_name)
# Out:
# dfitems.csv
# dfjuntado.csv
# dinero.csv
# items_count.csv
# respuesta3.csv
# steams.csv
# steamsmodels.csv

# %%
steams = pd.read_pickle('steams.pkl') # es la tabla steams
steams.to_csv('steams.csv', index=False)

# %%
dfreviews = pd.read_pickle('dfjuntado.pkl')
dfreviews = to

# %%
steamscsv = pd.read_csv('steams.csv')
steamscsv
# Out:
#                  publisher                                             genres  \
# 0                Kotoshiro  ['Action', 'Casual', 'Indie', 'Simulation', 'S...
# 1         Making Fun, Inc.       ['Free to Play', 'Indie', 'RPG', 'Strategy']
# 2             Poolians.com  ['Casual', 'Free to Play', 'Indie', 'Simulatio...
# 3                     彼岸领域                  ['Action', 'Adventure', 'Casual']
# 4      Trickjump Games Ltd              ['Action', 'Adventure', 'Simulation']
# ...                    ...                                                ...
# 27457      Bidoniera Games         ['Action', 'Adventure', 'Casual', 'Indie']
# 27458      Ghost_RUS Games      ['Casual', 'Indie', 'Simulation', 'Strategy']
# 27459               Sacada                    ['Casual', 'Indie', 'Strategy']
# 27460         Laush Studio                  ['Indie', 'Racing', 'Simulation']
# 27461             SIXNAILS                                ['Casual', 'Indie']
#
# ...
